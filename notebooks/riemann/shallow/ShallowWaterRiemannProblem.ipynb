# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set CLAW as environment variable before starting notebook, or specify as second argument below:

# %%
import os, sys
CLAW = os.environ.get('CLAW','/Users/rjl/git/clawpack')  
print CLAW
sys.path.append(CLAW)  # add to path so clawpack modules can be found
os.environ['CLAW'] = CLAW
os.environ['PYTHONPATH'] = CLAW  # so Fortran Makefiles work
# Out:
# /Users/rjl/git/clawpack

# %%
example_dir = CLAW + '/apps/notebooks/riemann/shallow'
os.chdir(example_dir)
print os.getcwd()
# Out:
# /Users/rjl/git/clawpack/apps/notebooks/riemann/shallow

# %%
import setrun
rundata = setrun.setrun()
outdir = '_output'

# %%
import glob
from matplotlib import image
from clawpack.visclaw.JSAnimation import IPython_display
from matplotlib import animation

def init():
    im.set_data(image.imread(filenames[0]))
    return im,

def animate(i):
    image_i=image.imread(filenames[i])
    im.set_data(image_i)
    return im,

# %% [markdown]
# ## Set up scripts to plot solution in phase plane $hu$ vs. $h$:

# %%
g = 1.  # gravitational constant used in book
def shallow_intcurve(hstar, hustar, wave_family='both'):
    ustar = hustar / hstar
    h = linspace(0,5,201)
    hu1 = h*ustar + 2*h*(sqrt(g*hstar) - sqrt(g*h))
    hu2 = h*ustar - 2*h*(sqrt(g*hstar) - sqrt(g*h))
    if wave_family in [1,'both']:
        plot(h,hu2,'m')
    if wave_family in [2,'both']:
        plot(h,hu1,'g')
    plot([hstar],[hustar],'ko',markersize=5)

def shallow_locus(hstar, hustar, wave_family='both'):
    ustar = hustar / hstar
    h = linspace(0,5,201)
    alpha = h - hstar
    d = sqrt(g*hstar*(1 + alpha/hstar)*(1 + alpha/(2*hstar)))
    hu1 = hustar + alpha*(ustar - d)
    hu2 = hustar + alpha*(ustar + d)
    if wave_family in [1,'both']:
        plot(h,hu2,'r')
    if wave_family in [2,'both']:
        plot(h,hu1,'b')
    plot([hstar],[hustar],'ko',markersize=5)

        
def make_axes_and_label(x1=-.5, x2=4.5, y1=-2.5, y2=2.5):
    plot([x1,x2],[0,0],'k')
    plot([0,0],[y1,y2],'k')
    axis([x1,x2,y1,y2])
    xlabel("h = depth",fontsize=15)
    ylabel("hu = momentum",fontsize=15)

# %% [markdown]
# ## Dam break Riemann problem:

# %%
rundata.probdata.hl = 3.0
rundata.probdata.ul = 0.0
rundata.probdata.hr = 1.0
rundata.probdata.ur = 0.0
rundata.write()

# %%
# %%system
# bash run_and_make_plots.sh
# Out:
# ['python(32171,0x7fff75847310) malloc: *** error for object 0x10225e210: pointer being freed was not allocated',
#  '*** set a breakpoint in malloc_error_break to debug',
#  'make: *** [plots] Abort trap: 6',
#  'see output.txt and plots.txt for system messages']

# %%
figno = 1
fname = '_plots/*fig' + str(figno) + '.png'
filenames=sorted(glob.glob(fname))

fig = plt.figure()
im = plt.imshow(image.imread(filenames[0]))

animation.FuncAnimation(fig, animate, init_func=init,
                              frames=len(filenames), interval=20, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, frame_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.frame_id = frame_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#     document.getElementById(this.frame_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img50fbf76768243f72" style="width:Nonepx">
#     <br>
#     <input id="_anim_slider50fbf76768243f72" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="anim50fbf76768243f72.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim50fbf76768243f72.slower()">&#8211;</button>
#     <button onclick="anim50fbf76768243f72.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim50fbf76768243f72.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim50fbf76768243f72.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim50fbf76768243f72.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim50fbf76768243f72.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim50fbf76768243f72.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim50fbf76768243f72.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim50fbf76768243f72.faster()">+</button>
#   <form action="#n" name="_anim_loop_select50fbf76768243f72" class="anim_control">
#     <input id="_frame_no50fbf76768243f72" type="textbox" size="1" onchange="anim50fbf76768243f72.set_frame(parseInt(this.value));" onpaste="this.onchange();" oninput="this.onchange();"></input>
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img50fbf76768243f72";
#     var slider_id = "_anim_slider50fbf76768243f72";
#     var frame_id = "_frame_no50fbf76768243f72"
#     var loop_select_id = "_anim_loop_select50fbf76768243f72";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAIABJREFUeJzt3XF8U/W9//F3auvmQ51CB+mWwFpoagmtFYSCbl7LoCDd\
# 2BCwW+ugwnB72M11uiGO+bjCHCTc6cOLc91j2wN093q3gXcbhV3oKtfVsYmtgLCtYVJKmU1aClrq\
# YGiL9Pv7gx+5VlImIcnJKa/n4+HDnnNyzudzaE/e+Z6cnDiMMUYAANhMitUNAAAQDQIMAGBLBBgA\
# wJYIMACALRFgAABbIsAAALZEgAEAbIkAAwDYEgEGALAlAgwAYEsEGADAlggwAIAtEWAAAFsiwAAA\
# tkSAAQBsiQADANgSAQYAsCUCDABgSwQYAMCWCDAAgC0RYAAAWyLAAAC2RIABAGyJAEtStbW1ys3N\
# lcfj0erVq61uBwCSjsMYY6xuAv2dPn1a1113nbZt2yaXy6WJEyfq5z//ucaMGWN1awCQNBiBJaHG\
# xkZlZ2crMzNTaWlp+vznP6+amhqr2wKApEKAJaFQKKQRI0aEp91ut0KhkIUdAUDyIcCSkMPhsLoF\
# AEh6qVY3gHO5XC61tbWFp9va2uR2u/s9Jjs7Wy0tLYluDbjkFRQUaM+ePVa3ATECS0oTJkxQc3Oz\
# Dh06pN7eXq1fv16f+cxn+j2mpaVFxpiE//fwww9fEjWpO3hrXmzdvXv3WvTMgPdiBJaEUlNT9eST\
# T2rGjBk6ffq0vvjFL3IFIgC8BwGWpGbOnKmZM2da3QYAJC1OIeKCFBUVXRI1qTt4a1pZF7HFB5lt\
# yuFwiF8dkHgce8mDERgAwJYIMACALRFgAABbIsAAALZEgAEAbIkAAwDYEgEGALAlAgwAYEsEGADA\
# lggwAIAtEWAAAFsiwAAAtkSA4ZK2atUqZWdnnzO/vb1dV1999T9dv7m5Wddee616enqiqn/69Omo\
# 1jsrKysr/PPixYslScuXL5ckVVVVSZKmTJmi3t5epaenq6WlRU6nU48//rimTp2qiRMn6plnnrmo\
# HgDLGNgSv7rYOHHihDl16pS5/PLLTUZGhqmqqjJFRUUmFAqZq666ynzqU58yxhiTnZ1tnnrqqYjb\
# cLlc5ic/+Yl56KGHTFZWlvnxj39sjDFm5MiR5uTJk+HH3X777eese/jw4X7TI0eOvOB9WLRo0YDL\
# 3nzzTWOMMd/4xjfMqVOnzMiRI83vfvc7M3LkSHP77bebxx9/3KSlpV1wzUsZx17y4OtUbCreX+kw\
# e/Zsbdy4UXv27NENN9wQtzrJ5lvf+pZ8Pp/VbSCJ8XUqyYMAs6l4H0R//OMf9fGPfzw8PXr06LjV\
# irVjx45pyJAhVrcBi/X29qqtrS3m2yXAkgcBZlMcRAN76623dMUVV1jdBiwWCATk9Xpjvl2OveTB\
# RRwYdAgv4NJAgAEAbIkAi7O2tjZNmTJFY8eOVV5enp544glJUldXl4qLi5WTk6Pp06eru7s7vI7P\
# 55PH41Fubq7q6uqsah0AkhoBFmdpaWl6/PHH1dTUpJdeekk/+MEPtG/fPvn9fhUXF2v//v2aOnWq\
# /H6/pDPn7devX69AIKDa2lpVVlaqr6/P4r0AgORDgMVZRkZG+DL0q666SmPGjFEoFNKmTZtUUVEh\
# SaqoqNDGjRslSTU1NSorK1NaWpoyMzOVnZ2txsZGy/oHgGRFgCXQoUOH9Morr2jSpEnq7OyU0+mU\
# JDmdTnV2dko6cwcIt9sdXsftdisUClnSLwAkMwIsQU6cOKG5c+dqzZo159yiyOFwyOFwDLju+ZYB\
# wKUq1eoGLgWnTp3S3LlzNX/+fM2ePVvSmVHX4cOHlZGRoY6ODg0fPlyS5HK5+n34MhgMyuVyRdzu\
# 2XveSVJRUZGKioritg/Apaq+vl719fVWt4EI+CBznBljVFFRofT0dD3++OPh+Q888IDS09O1dOlS\
# +f1+dXd3y+/3KxAIqLy8XI2NjQqFQpo2bZoOHDhwzigs3h+m7Orq0tChQ/W3v/1NH/vYx+JWB4gX\
# Psg8+BFgcfaHP/xB//Iv/6Lrr78+HEI+n0+FhYUqLS3Va6+9pszMTG3YsEHXXnutpDN3SF+3bp1S\
# U1O1Zs0azZgx45ztxvsgGjt2rJqamsLTy5Yti1utS92qVausbmFQIsAGPwLMpuJ9EDU0NCgvL08/\
# /OEP9c1vflPatWvgB0+YMPCyYcOkrV

# %% [markdown]
# ## Symmetric impinging flow modeling wall at x=0 with flow towards wall:

# %%
hl = 2.
ul = 1.
hr = 2.
ur = -1.
rundata.probdata.hl = hl
rundata.probdata.ul = ul
rundata.probdata.hr = hr
rundata.probdata.ur = ur
rundata.write()

# %%
# %%system
# bash run_and_make_plots.sh
# Out:
# ['python(32259,0x7fff75847310) malloc: *** error for object 0x100b61410: pointer being freed was not allocated',
#  '*** set a breakpoint in malloc_error_break to debug',
#  'make: *** [plots] Abort trap: 6',
#  'see output.txt and plots.txt for system messages']

# %%
fig = plt.figure()
im = plt.imshow(image.imread(filenames[0]))

animation.FuncAnimation(fig, animate, init_func=init,
                              frames=len(filenames), interval=20, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, frame_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.frame_id = frame_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#     document.getElementById(this.frame_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc6d0769edb44c0e7" style="width:Nonepx">
#     <br>
#     <input id="_anim_sliderc6d0769edb44c0e7" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animc6d0769edb44c0e7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc6d0769edb44c0e7.slower()">&#8211;</button>
#     <button onclick="animc6d0769edb44c0e7.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animc6d0769edb44c0e7.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animc6d0769edb44c0e7.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animc6d0769edb44c0e7.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animc6d0769edb44c0e7.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animc6d0769edb44c0e7.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animc6d0769edb44c0e7.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animc6d0769edb44c0e7.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectc6d0769edb44c0e7" class="anim_control">
#     <input id="_frame_noc6d0769edb44c0e7" type="textbox" size="1" onchange="animc6d0769edb44c0e7.set_frame(parseInt(this.value));" onpaste="this.onchange();" oninput="this.onchange();"></input>
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc6d0769edb44c0e7";
#     var slider_id = "_anim_sliderc6d0769edb44c0e7";
#     var frame_id = "_frame_noc6d0769edb44c0e7"
#     var loop_select_id = "_anim_loop_selectc6d0769edb44c0e7";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAIABJREFUeJzt3X14U/X9//FXasvchTfcaNMtgbW0qSW01hsozM0ZB+Wm\
# E4eAdS2DKtPtGpt2w0Edel2DOWjZ5hzOdde2C5RLdiNujuIGrDJXdUMLgrKNMKm1HUlaqljqYCjF\
# 9vP7gy/5WUlRYpKTU56P6/KyOSfn834f2tNXPienJw5jjBEAADaTYnUDAABEgwADANgSAQYAsCUC\
# DABgSwQYAMCWCDAAgC0RYAAAWyLAAAC2RIABAGyJAAMA2BIBBgCwJQIMAGBLBBgAwJYIMACALRFg\
# AABbIsAAALZEgAEAbIkAAwDYEgEGALAlAgwAYEsEGADAlggwAIAtEWAAAFsiwJLUli1blJeXJ4/H\
# o5UrV1rdDgAkHYcxxljdBPrq6enRJZdcoq1bt8rlcmncuHH6zW9+o9GjR1vdGgAkDWZgSWj79u3K\
# yclRZmam0tLS9IUvfEF1dXVWtwUASYUAS0KhUEgjRowIP3a73QqFQhZ2BADJhwBLQg6Hw+oWACDp\
# pVrdAE7lcrkUCATCjwOBgNxud5/n5OTkqLm5OdGtAWe9wsJCvfTSS1a3ATEDS0pjx45VU1OTWltb\
# 1d3drUcffVTXX399n+c0NzfLGJPw/77zne+cFTWpO3Brfti6u3fvtug3A96LGVgSSk1N1YMPPqgp\
# U6aop6dHX/rSl7gCEQDegwBLUtOmTdO0adOsbgMAkhanEHFGfD7fWVGTugO3ppV1EVv8IbNNORwO\
# 8a0DEo9jL3kwAwMA2BIBBgCwJQIMAGBLBBgAwJYIMACALRFgAABbIsAAALZEgAEAbIkAAwDYEgEG\
# ALAlAgwAYEsEGADAlggwnNVWrFihnJycU5a3tbXp/PPPf9/tm5qaNGTIEB07diyq+j09PVFtd1JW\
# Vlb461tvvVWStHTpUklSZWWlJOnaa69Vd3e3hg8frubmZjmdTt1///2aOHGixo0bp3Xr1n2oHgDL\
# GNgS37rYOHLkiDl+/LgZNGiQycjIMJWVlcbn85lQKGTOO+8887nPfc4YY0xOTo556KGHIo7hcrnM\
# L3/5S3PPPfeYrKws84tf/MIYY8zIkSPN0aNHw8+74YYbTtn2wIEDfR6PHDnyjPdh/vz5/a578803\
# jTHG3Hnnneb48eNm5MiR5q9//asZOXKkueGGG8z9999v0tLSzrjm2YxjL3nwcSo2Fe+PdJgxY4Y2\
# bNigl156SZdddlnc6iSbb3/726qurra6DSQxPk4leRBgNhXvg+jvf/+7PvWpT4UfZ2dnx61WrB06\
# dEhDhw61ug1YrLu7W4FAIObjEmDJgwCzKQ6i/r311lv66Ec/anUbsJjf75fX6435uBx7yYOLODDg\
# EF7A2YEAAwDYEgEWZ4FAQNdee63GjBmj/Px8PfDAA5Kkzs5OFRcXKzc3V5MnT1ZXV1d4m+rqank8\
# HuXl5am+vt6q1gEgqRFgcZaWlqb7779fe/bs0fPPP6+f/vSn2rt3r2pqalRcXKx9+/Zp4sSJqqmp\
# kXTivP2jjz4qv9+vLVu2aMGCBert7bV4LwAg+RBgcZaRkRG+DP28887T6NGjFQqFtHHjRlVUVEiS\
# KioqtGHDBklSXV2dysrKlJaWpszMTOXk5Gj79u2W9Q8AyYoAS6DW1la9+OKLGj9+vDo6OuR0OiVJ\
# TqdTHR0dkk7cAcLtdoe3cbvdCoVClvQLAMmMAEuQI0eOaNasWVq1atUptyhyOBxyOBz9bnu6dQBw\
# tkq1uoGzwfHjxzVr1izNnTtXM2bMkHRi1nXgwAFlZGSovb1d6enpkiSXy9Xnjy+DwaBcLlfEcU/e\
# 806SfD6ffD5f3PYBOFs1NDSooaHB6jYQAX/IHGfGGFVUVGj48OG6//77w8sXL16s4cOHq6qqSjU1\
# Nerq6lJNTY38fr/Ky8u1fft2hUIhTZo0Sa+88sops7B4/zFlZ2enhg0bpv/85z/6xCc+Ebc6QLzw\
# h8wDHwEWZ3/729/0mc98Rpdeemk4hKqrq1VUVKTS0lLt379fmZmZWr9+vYYMGSLpxB3S16xZo9TU\
# VK1atUpTpkw5Zdx4H0RjxozRnj174jY+EG8E2MBHgNlUvA+ixsZG5efn62c/+5m+9a1vxa0OEC8E\
# 2MBHgNkUBxFwegTYwMdViAAAWyLAAA

# %% [markdown]
# The phase plane solution in this case consists of two shock waves and the intermediate state is where the 2-wave Hugoniot locus from $(h_l,h_lu_l)$ intersects the 1-wave Hugoniot locus from $(h_r,h_ru_r)$

# %%
shallow_locus(hl, hl*ul, wave_family=2)
shallow_locus(hr, hr*ur, wave_family=1)
make_axes_and_label()

# %%
hl = 2.
ul = -1.
hr = 2.
ur = 1.
rundata.probdata.hl = hl
rundata.probdata.ul = ul
rundata.probdata.hr = hr
rundata.probdata.ur = ur
rundata.write()

# %%
shallow_intcurve(hl, hl*ul, wave_family=2)
shallow_intcurve(hr, hr*ur, wave_family=1)
make_axes_and_label()
